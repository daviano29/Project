# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
print('Numpy version :',np.__version__)
print('Pandas Version :',pd.__version__)
# Out:
# Numpy version : 1.16.4
# Pandas Version : 0.23.4

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Datasets/Fifa.csv", 
                 encoding='UTF-8', sep=',', skiprows=0, index_col=False)
data = pd.DataFrame(df)
df.head()
# Out:
#    Number      ID               Name  Age  \
# 0       0  158023           L. Messi   31
# 1       1   20801  Cristiano Ronaldo   33
# 2       2  190871          Neymar Jr   26
# 3       3  193080             De Gea   27
# 4       4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club      ...       Composure Marking StandingTackle  \
# 0         FC Barcelona      ...            96.0    33.0           28.0
# 1             Juventus      ...            95.0    28.0           31.0
# 2  Paris Saint-Germain      ...            94.0    27.0           24.0
# 3    Manchester United      ...            68.0    15.0           21.0
# 4      Manchester City      ...            88.0    68.0           58.0
#
#    SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0           26.0      6.0        11.0       15.0           14.0        8.0
# 1           23.0      7.0        11.0       15.0           14.0       11.0
# 2           33.0      9.0         9.0       15.0           15.0       11.0
# 3           13.0     90.0        85.0       87.0           88.0       94.0
# 4           51.0     15.0        13.0        5.0           10.0       13.0
#
#   Release_Clause
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#
# [5 rows x 89 columns]

# %%
#Copying Data Frame
df1=df.copy()

# %%
#Removing Unecessary Column
df1.drop(['Joined','Contract Valid Until',
        "Photo","Flag","Club Logo","Special","ID",'Preferred Foot','Real Face',
        'Jersey Number','Loaned From','LS','ST','RS','LW','LF','CF',
        'RF','RW','LAM','CAM','RAM','LM', 'LB','LCB','CB','RCB',
        'RB','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB',
          'StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','Number','Release_Clause'  ],
        axis=1, inplace=True)

# %%
## Converting to numeric Format

def convert_to_numeric(df_value):
    try:
        value = float(df_value[1:-1])
        suffix = df_value[-1:]
        if suffix == 'M':
            value = value * 1000000
        elif suffix == 'K':
            value = value * 1000
    except ValueError:
        value = 0
    return value

# %%
## Appliying The Function

df1['Value'] = df1['Value'].apply(convert_to_numeric)
df1['Wage'] = df1['Wage'].apply(convert_to_numeric)
df1.Value = df1.Value.replace(0, np.nan)
df1.Wage = df1.Wage.replace(0, np.nan)
df1.head(3)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
#
#                   Club        Value      Wage  International Reputation  \
# 0         FC Barcelona  110500000.0  565000.0                       5.0
# 1             Juventus   77000000.0  405000.0                       5.0
# 2  Paris Saint-Germain  118500000.0  290000.0                       5.0
#
#    Weak Foot     ...      Strength LongShots Aggression Interceptions  \
# 0        4.0     ...          59.0      94.0       48.0          22.0
# 1        4.0     ...          79.0      93.0       63.0          29.0
# 2        5.0     ...          49.0      82.0       56.0          36.0
#
#   Positioning Vision  Penalties  Composure  Marking  GKReflexes
# 0        94.0   94.0       75.0       96.0     33.0         8.0
# 1        95.0   82.0       85.0       95.0     28.0        11.0
# 2        89.0   87.0       81.0       94.0     27.0        11.0
#
# [3 rows x 44 columns]

# %%
##Separating Work Rate
df1['Work_Rate'] = df1['Work_Rate'].astype(str)
df1['Work_Rate'] = df1['Work_Rate'].str.split('/')
df1['Attacking_rates']=df1['Work_Rate'].str.get(0)
df1['Attacking_rates'] = df1['Attacking_rates'].str.strip()
df1['Defensive_rates'] = df1['Work_Rate'].str.get(1)
df1['Defensive_rates'] = df1['Defensive_rates'].str.strip()

# %%
df1.dtypes
df1.head(10)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
# 5          E. Hazard   27     Belgium       91         91
# 6          L. Modrić   32     Croatia       91         91
# 7          L. Suárez   31     Uruguay       91         91
# 8       Sergio Ramos   32       Spain       91         91
# 9           J. Oblak   25    Slovenia       90         93
#
#                   Club        Value      Wage  International Reputation  \
# 0         FC Barcelona  110500000.0  565000.0                       5.0
# 1             Juventus   77000000.0  405000.0                       5.0
# 2  Paris Saint-Germain  118500000.0  290000.0                       5.0
# 3    Manchester United   72000000.0  260000.0                       4.0
# 4      Manchester City  102000000.0  355000.0                       4.0
# 5              Chelsea   93000000.0  340000.0                       4.0
# 6          Real Madrid   67000000.0  420000.0                       4.0
# 7         FC Barcelona   80000000.0  455000.0                       5.0
# 8          Real Madrid   51000000.0  380000.0                       4.0
# 9      Atlético Madrid   68000000.0   94000.0                       3.0
#
#    Weak Foot       ...         Aggression Interceptions Positioning Vision  \
# 0        4.0       ...               48.0          22.0        94.0   94.0
# 1        4.0       ...               63.0          29.0        95.0   82.0
# 2        5.0       ...               56.0          36.0        89.0   87.0
# 3        3.0       ...               38.0          30.0        12.0   68.0
# 4        5.0       ...               76.0          61.0        87.0   94.0
# 5        4.0       ...               54.0          41.0        87.0   89.0
# 6        4.0       ...               62.0          83.0        79.0   92.0
# 7        4.0       ...               87.0          41.0        92.0   84.0
# 8        3.0       ...               88.0          90.0        60.0   63.0
# 9        3.0       ...               34.0          19.0        11.0   70.0
#
#   Penalties Composure  Marking  GKReflexes  Attacking_rates  Defensive_rates
# 0      75.0      96.0     33.0         8.0           Medium           Medium
# 1      85.0      95.0     28.0        11.0             High              Low
# 2      81.0      94.0     27.0        11.0             High           Medium
# 3      40.0      68.0     15.0        94.0           Medium           Medium
# 4      79.0      88.0     68.0        13.0             High             High
# 5      86.0      91.0     34.0         8.0             High           Medium
# 6      82.0      84.0     60.0         9.0             High             High
# 7      85.0      85.0     62.0        37.0             High           Medium
# 8      75.0      82.0     87.0        11.0             High           Medium
# 9      11.0      70.0     27.0        89.0           Medium           Medium
#
# [10 rows x 46 columns]

# %%
#Fixing Body Type
df1.loc[df['Body Type'] == "Lean", 'Body Type'] = 1
df1.loc[df['Body Type'] == "Normal", 'Body Type'] = 2
df1.loc[df['Body Type'] == "Stocky", 'Body Type'] = 3
df1.loc[df['Body Type'] == "Messi", 'Body Type'] = 2
df1.loc[df['Body Type'] == "C. Ronaldo", 'Body Type'] = 2
df1.loc[df['Body Type'] == "Neymar", 'Body Type'] = 1
df1.loc[df['Body Type'] == "Courtois", 'Body Type'] = 2
df1.loc[df['Body Type'] == "Shaqiri", 'Body Type'] = 3
df1.loc[df['Body Type'] == "Akinfenwa", 'Body Type'] = 3
df1.loc[df['Body Type'] == "PLAYER_BODY_TYPE_25", 'Body Type'] = np.nan

# %%
##Droping Body Type that have "nan" values and changing Body Type column into int 
df1.dropna(subset=['Body Type'], inplace=True)
df1['Body Type'].astype('int64')
# Out:
# 0        2
# 1        2
# 2        1
# 3        1
# 4        2
# 5        2
# 6        1
# 7        2
# 8        2
# 9        2
# 10       2
# 11       2
# 12       1
# 13       2
# 14       1
# 15       2
# 16       2
# 17       1
# 18       2
# 19       2
# 20       1
# 21       1
# 22       2
# 23       3
# 24       2
# 25       1
# 27       2
# 28       2
# 29       2
# 30       2
#         ..
# 18177    1
# 18178    1
# 18179    1
# 18180    1
# 18181    1
# 18182    1
# 18183    2
# 18184    2
# 18185    2
# 18186    2
# 18187    1
# 18188    1
# 18189    1
# 18190    2
# 18191    1
# 18192    1
# 18193    1
# 18194    2
# 18195    2
# 18196    1
# 18197    2
# 18198    1
# 18199    1
# 18200    1
# 18201    1
# 18202    1
# 18203    2
# 18204    2
# 18205    1
# 18206    1
# Name: Body Type, Length: 18158, dtype: int64

# %%
df1.head(5)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage  International Reputation  \
# 0         FC Barcelona  110500000.0  565000.0                       5.0
# 1             Juventus   77000000.0  405000.0                       5.0
# 2  Paris Saint-Germain  118500000.0  290000.0                       5.0
# 3    Manchester United   72000000.0  260000.0                       4.0
# 4      Manchester City  102000000.0  355000.0                       4.0
#
#    Weak Foot       ...         Aggression Interceptions Positioning Vision  \
# 0        4.0       ...               48.0          22.0        94.0   94.0
# 1        4.0       ...               63.0          29.0        95.0   82.0
# 2        5.0       ...               56.0          36.0        89.0   87.0
# 3        3.0       ...               38.0          30.0        12.0   68.0
# 4        5.0       ...               76.0          61.0        87.0   94.0
#
#   Penalties Composure  Marking  GKReflexes  Attacking_rates  Defensive_rates
# 0      75.0      96.0     33.0         8.0           Medium           Medium
# 1      85.0      95.0     28.0        11.0             High              Low
# 2      81.0      94.0     27.0        11.0             High           Medium
# 3      40.0      68.0     15.0        94.0           Medium           Medium
# 4      79.0      88.0     68.0        13.0             High             High
#
# [5 rows x 46 columns]

# %%
#Make Variable and column name lower case and export in into clean csv
df1.columns = map(str.lower, df1.columns)
df1.to_csv(r"C:\Users\HP\Desktop\Datasets/Fifa_cleaned.csv")
